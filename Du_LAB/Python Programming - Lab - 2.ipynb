# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404 </b></center>
# <center><b><h1>Lab - 2</b></center>
# <center><b><h1> Vishwrajsinh Jadeja 24010101107</b></center>
#
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("Hello World...!")
# Out:
# Hello World...!

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name= input("Enter Name")
print("Hello" ,name,"welcome to Python Lab")
# Out:
# Hello  welcome to Python Lab

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
# num1 = int(input("Enter number 1"))
# num2 = int(input("enter number 2"))
# num3 = int(input("enter number 3"))



# single input method
a,b,c = input().split()
a=int(a)
b=int(b)
c=int(c)
sum =a+b+c
Avg = sum/3
print("sum :",sum)
print("AVG :",Avg)
# Out:
#  1 25 799
# sum : 825
# AVG : 275.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
Name,Age,Percent = input().split(",")
Name=str(Name)
Age=int(Age)
Percent=float(Percent)

print("Name:",Name, "Type:", type(name))
print("Age:",Age, "Type:", type(Age))
print("Percent:",Percent, "Type:", type(Percent))
# Out:
#  abc,29,78.45
# Name: abc Type: <class 'str'>
# Age: 29 Type: <class 'int'>
# Percent: 78.45 Type: <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("Python","Programming","Basics",sep='|',end='###')
# Out:
# Python|Programming|Basics###

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
name =input("enter a message")
print("value:",name)
print("Type:",type(name))
print("ID:",id(name))
# Out:
# enter a message hello
# value: hello
# Type: <class 'str'>
# ID: 2095090119616

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
name =input("enter a message")
print("Original ID of",name,":",id(name))

name =input("enter a message")
print("New ID of",name,":",id(name))
# Out:
# enter a message vishwrajsinh
# Original ID of vishwrajsinh : 2095102168944
# enter a message jadeja
# New ID of jadeja : 2095090117168

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("Welcome to Python" ,"This is the Second Lab","Enjoy Coding" , sep="\n")
# Out:
# Welcome to Python
# This is the Second Lab
# Enjoy Coding

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
# Display table in clean aligned format

print("| {:>5} | {:<12} | {:<8} | {:^7} | {:>10} |".format("Sr No", "Name", "Subject", "Grade", "Percentage"))
print("| {:>5} | {:<12} | {:<8} | {:^7} | {:>10} |".format(1, "Nisha Patel", "Math", "A", 92))
print("| {:>5} | {:<12} | {:<8} | {:^7} | {:>10} |".format(2, "Aarav Modi", "Science", "B+", 85))
print("| {:>5} | {:<12} | {:<8} | {:^7} | {:>10} |".format(3, "Jiya Shah", "English", "A+", 96))
# Out:
# | Sr No | Name         | Subject  |  Grade  | Percentage |
# |-------|--------------|----------|-----------|---------|
# |     1 | Nisha Patel  | Math     |    A    |         92 |
# |     2 | Aarav Modi   | Science  |   B+    |         85 |
# |     3 | Jiya Shah    | English  |   A+    |         96 |

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
num = float(input("Enter a float number:"))

print("2 decimal",round(num,2))
print("3 decimal",round(num,3))
print(f"Width 10:{num:10.2f}")
# Out:
# Enter a float number: 12.56598777979
# 2 decimal 12.57
# 3 decimal 12.566
# Width 10:     12.57

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a,b = input().split(" ")
a= int(a)
b= int(b)
sum = a+b
sub= a-b
mul = a*b
print(f"sum is{sum} \n subtraction is {sub}\n multiplication is {mul}\n")
# Out:
#  1 15
# sum is16
#  subtraction is -14
#  multiplication is 15

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
d,m,y = input().split(" ")
print(f"{d}/{m}/{y}\n{y}-{m}-{d}")
# Out:
#  01 12 2025
# 01/12/2025
#  2025-12-01

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
import math
radii = int(input("enter a circle radii"))

area = 2*radii*radii*math.pi
perimeter = 2*math.pi*radii
print("area:",area)
print("perimeter",perimeter)
# Out:
# enter a circle radii 4
# area: 100.53096491487338
# perimeter 25.132741228718345

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
degree = float(input("Enter temperature in degree celsisus"))
print ("converting in the frahrenheit")
frahrenheit = float ((degree * 9/5) +32)
print("the given temp in celsius",degree, "same in frahrenheit",frahrenheit)

getfrahrenheit= float(input("Enter the temp in frahrenheit"))
print("converting in celsisus")
celsisus = (((getfrahrenheit-32)*5)/9)
print("the given temp in frahrenheit",getfrahrenheit, "same in celsius",celsisus)
# Out:
# converting in the frahrenheit
# the given temp in celsius -40.0 same in frahrenheit -40.0
# converting in celsisus
# the given temp in frahrenheit 32.0 same in celsius 0.0

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input("give the distance in Kms "))

meteres = km*1000
cm = meteres*100
inches=cm/2.54
feet=inches/12

print("Kilometers : ",km)
print("Meters  : ",meteres)
print("Centimeters : ",cm)
print("Inches : ",inches)
print("Feet : ",feet)
# Out:
# Kilometers :  1.0
# Meters  :  1000.0
# Centimeters :  100000.0
# Inches :  39370.07874015748
# Feet :  3280.839895013123
