# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
#     <center><b><h1>Python Programming - </b></center>
# <center><b><h1>Lab - 10</b></center>
# <center><b><h3>Roll No : 360</b></center>
# <center><b><h3>Name :Jadeja Vishwrajsinh</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
# 1) Read file as a string
f1 = open("file1.txt", "r")
print("File as string:")
print(f1.read())
f1.close()


# 2) Read file line by line
f2 = open("C:\\R drive\\Python\\Files\\file1.txt", "r")
print("File line by line:")
for line in f2:
    print(line)
f2.close()


# 3) Read file as a list
f3 = open("C:\\R drive\\Python\\Files\\file1.txt", "r")
print("File as list:")
print(f3.readlines())
f3.close()
# Out:
# File as string:
# This is file 1
# File line by line:
# This is 1st line from file1.txt
#
# This is 2nd line
#
# This is 3rd line
# File as list:
# ['This is 1st line from file1.txt\n', 'This is 2nd line \n', 'This is 3rd line']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
f = open("new.txt", "w")
print("File new.txt created successfully")
f.close()
# Out:
# File new.txt created successfully

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
f = open("file1.txt", "r")
for i in range(5):
    print(f.readline())
f.close()
# Out:
# This is 1st line from file1.txt
#
# This is 2nd line
#
# This is 3rd line
#
# This is 4th line
#
# This is 5th line

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file.

# %%
f = open("file1.txt", "r")
words = f.read().split()
f.close()

longest = ""

for w in words:
    if len(w) > len(longest):
        longest = w

print("Longest word:", longest)
# Out:
# Longest word: thisIStheLONGESTwordINtheFILE

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
f = open("file1.txt", "r")

lines = f.readlines()
f.close()

line_count = len(lines)
word_count = 0
char_count = 0

for line in lines:
    word_count = word_count + len(line.split())
    char_count = char_count + len(line)

print("Number of lines:", line_count)
print("Number of words:", word_count)
print("Number of characters:", char_count)
# Out:
# Number of lines: 6
# Number of words: 23
# Number of characters: 130

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
f1 = open("file1.txt", "r")
data = f1.read()
f1.close()

f2 = open("copy.txt", "w")
f2.write(data)
f2.close()

print("File copied successfully")
# Out:
# File copied successfully

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
fp = open("file1.txt")
fp.read()
print("Total size = ",fp.tell(),"kb")
fp.close()
# Out:
# Total size =  140 kb

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def frequency(word):
    f = open("file1.txt", "r")
    data = f.read()
    f.close()

    words = data.split()
    count = 0

    for w in words:
        if w == word:
            count = count + 1

    return count


search = input("Enter word to search: ")
print("Frequency:", frequency(search))
# Out:
# Enter word to search:  is
# Frequency: 5

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
f = open("marks.txt", "w")

for i in range(5):
    m = int(input("Enter marks: "))
    f.write(str(m) + "\n")

f.close()

f = open("marks.txt", "r")
marks = f.readlines()
f.close()

highest = int(marks[0])

for m in marks:
    if int(m) > highest:
        highest = int(m)

print("Highest score:", highest)
# Out:
# Enter marks:  5
# Enter marks:  4
# Enter marks:  3
# Enter marks:  2
# Enter marks:  1
# Highest score: 5

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
f = open("primenumbers.txt", "w")
count = 0
num = 2
while count < 100:
    prime = True
    for i in range(2, num):
        if num % i == 0:
            prime = False
            break
    if prime:
        f.write(str(num) + "\n")
        count = count + 1
    num = num + 1
f.close()

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
f1 = open("file1.txt", "r")
data1 = f1.read()
f1.close()

f2 = open("file2.txt", "r")
data2 = f2.read()
f2.close()

f3 = open("merged.txt", "w")
f3.write(data1)
f3.write(data2)
f3.close()

print("Files merged successfully")
# Out:
# Files merged successfully

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %%
f = open("file1.txt", "r")
data = f.read()
f.close()

word1 = input("Enter word to replace: ")
word2 = input("Enter new word: ")

new_data = data.replace(word1, word2)

f2 = open("updated.txt", "w")
f2.write(new_data)
f2.close()

print("Word replaced and data written to new file")
# Out:
# Enter word to replace:  2323323232
# Enter new word:  2323232
# Word replaced and data written to new file

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.

# %% [markdown]
# #seek
# seek(offset, from_where)
# from_where:
# 0 - from beginning of the field
# 1 - from current position of the file pointer
# 2 - from end of the

# %%
# f1 = open('file1.txt')
# f1.read(5)
# myLen = f1.tell()
# f1.seek(myLen,0)
# f1.seek(3,1)
# help(f1.seek)
# print(f1.tell())
# f1.close()


with open('seek_demo.txt', 'w') as f:
    f.write('helloworldfrompythonlab')

with open('seek_demo.txt', 'r') as f:
    print(f"Initial position: {f.tell()}")

    f.seek(0, 0)
    print(f"Position : {f.tell()}")
    f.read(5)
    f.seek(0, 1)
    print(f"Position: {f.tell()}")

    f.seek(0, 2)
    print(f"Position : {f.tell()}")
# Out:
# Initial position: 0
# Position : 0
# Position: 5
# Position : 23

# %%
# Define Python user-defined exception
class NegativeNumberException(BaseException):
    "Raised when the input value is less than 0"
    pass

try:
    a = int(input("Enter Number: "))

    if a > 0:
        print(a)
    else:
        raise NegativeNumberException("Number is negative")

except NegativeNumberException as e:
    print(e)
# Out:
# Enter Number:  -1
# Number is negative
