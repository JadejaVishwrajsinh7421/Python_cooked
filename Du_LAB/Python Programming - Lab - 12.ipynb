# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No : 340</b></center>
# <center><b><h3>Name : Rakshit Gajera</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    
    result = num1 / num2
    print("Result:", result)

except (ZeroDivisionError, ValueError, TypeError) as e:
    print("Error occurred:", e)
# Out:
# Enter first number:  1
# Enter second number:  0
# Error occurred: division by zero

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    numbers = [10, 20, 30, 40]
    index = int(input("Enter index number (0-3): "))
    print("Value at index:", numbers[index])

    student = {"name": "Rakshit", "age": 20}
    key = input("Enter key to search (name/age): ")
    print("Value for key:", student[key])

except (IndexError, KeyError, ValueError) as e:
    print("Error occurred:", e)
# Out:
# Enter index number (0-3):  1
# Value at index: 20
# Enter key to search (name/age):  2
# Error occurred: '2'

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    filename = input("Enter file name to open: ")
    file = open(filename, "r")
    print(file.read())
    file.close()

    module_name = input("Enter module name to import: ")
    __import__(module_name)

    print("Module imported successfully!")

except (FileNotFoundError, ModuleNotFoundError) as e:
    print("Error occurred:", e)
# Out:
# Enter file name to open:  mytxt
# Error occurred: [Errno 2] No such file or directory: 'mytxt'

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    result = num1 / num2
    print("Result:", result)

except Exception as e:
    print("Error:", type(e).__name__, "-", e)
# Out:
# Enter first number:  1
# Enter second number:  0
# Error: ZeroDivisionError - division by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
# Program to demonstrate else and finally

try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    result = num1 / num2

except ZeroDivisionError:
    print("Error: Cannot divide by zero!")

except ValueError:
    print("Error: Please enter valid numbers!")

else:
    # Executes only if no exception occurs
    print("Result:", result)
    print("No errors occurred!")

finally:
    # Always executes
    print("Program execution completed.")
# Out:
# Enter first number:  1
# Enter second number:  0
# Error: Cannot divide by zero!
# Program execution completed.

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
# Function to divide two numbers

def divide(a, b):
    try:
        result = a / b
        print("Result:", result)
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")

# Taking input from user
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

divide(num1, num2)
# Out:
# Enter first number:  1
# Enter second number:  0
# Error: Cannot divide by zero!

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
# Program to calculate total bill amount

total = 0

try:
    n = int(input("Enter number of items: "))

    for i in range(n):
        price = float(input(f"Enter price of item {i+1}: "))

        if price < 0:
            raise ValueError("Price cannot be negative!")

        total += price

    print("Total Bill Amount:", total)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter number of items:  2
# Enter price of item 1:  1
# Enter price of item 2:  2
# Total Bill Amount: 3.0

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
# Program to convert grades into integers

try:
    grades_input = input("Enter grades separated by commas: ")
    
    grades = [int(g.strip()) for g in grades_input.split(",")]
    
    print("Grades List:", grades)

except ValueError:
    print("Error: Please enter only integer values separated by commas!")
# Out:
# Enter grades separated by commas:  A,B,C
# Error: Please enter only integer values separated by commas!

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
# Program to accept 5 subject marks and validate using assert

try:
    marks = []
    
    for i in range(5):
        m = int(input("Enter marks: "))
        assert 0 <= m <= 100, "Marks should be between 0 and 100."
        marks.append(m)
    
    print("Valid marks entered")
    print("Average Marks:", sum(marks) / 5)

except AssertionError as e:
    print("AssertionError:", e)

except ValueError:
    print("Error: Please enter integer values only!")
# Out:
# Enter marks:  90
# Enter marks:  90
# Enter marks:  10
# Enter marks:  10
# Enter marks:  10
# Valid marks entered
# Average Marks: 42.0

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
# Creating custom exception
class WeakPasswordError(Exception):
    pass

try:
    password = input("Enter password: ")

    # Check conditions
    if len(password) < 8 or not any(char.isdigit() for char in password):
        raise WeakPasswordError("Password must be at least 8 characters long and contain at least one digit.")

    print("Correct")

except WeakPasswordError as e:
    print("WeakPasswordError:", e)
# Out:
# Enter password:  Manas
# WeakPasswordError: Password must be at least 8 characters long and contain at least one digit.

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
class NegativeNumberError(Exception):
    pass

import math

try:
    num = float(input("Enter a number: "))

    if num < 0:
        raise NegativeNumberError("Cannot calculate the square root of a negative number")

    print("Square Root:", math.sqrt(num))

except NegativeNumberError as e:
    print("NegativeNumberError:", e)

except ValueError:
    print("Error: Please enter a valid number!")
# Out:
# Enter a number:  -2
# NegativeNumberError: Cannot calculate the square root of a negative number
