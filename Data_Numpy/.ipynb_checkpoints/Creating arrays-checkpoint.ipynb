# %% [markdown]
# Array

# %%
import numpy as np

x = [1,2,3,4]

# converting list in array

y = np.array(x)
print(y)
y
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])

# %%
l = []
for i in range(1,11):
    int_ = int(input("Enter the elements"))
    l.append(int_)
# Out:
# Enter the elements 45
# Enter the elements 778
# Enter the elements 45
# Enter the elements 74
# Enter the elements 41296
# Enter the elements 45
# Enter the elements 85
# Enter the elements 963
# Enter the elements 213
# Enter the elements 78

# %%
arr1 = np.array(l)

print(arr1)
# Out:
# [   45   778    45    74 41296    45    85   963   213    78]

# %%
#  2-D arrays

# %%
import  numpy as np
arr2 =  np.array([[1,2,3,4,5],[1,232,45,23,21]])
print(arr2)
print(arr2.ndim)
# Out:
# [[  1   2   3   4   5]
#  [  1 232  45  23  21]]
# 2

# %%
arr3 =   np.array([[[12,45,78],[23,45,79],[23,56,96]]])
print(arr3 , arr3.ndim)
# Out:
# [[[12 45 78]
#   [23 45 79]
#   [23 56 96]]] 3
