# %%
import numpy as np

x = np.array([1,2,3,4])
print(x)
print(type(x))
print(x.ndim)
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# 1

# %%
y = [1,2,3,4]
print(y)
print(type(y))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
 # %timeit [j**4 for j in range(1,12)]
# Out:
# 619 ns ± 14.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit np.arange(1,9)**4
# Out:
# 1.35 μs ± 35.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
